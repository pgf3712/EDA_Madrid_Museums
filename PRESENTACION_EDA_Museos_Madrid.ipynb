# %% [markdown]
# # Análisis de datos de las visitas a los Museos de Madrid

# %% [markdown]
# ![cris](./img/cristina_garcia_rodero.png)

# %% [markdown]
# # Análisis de datos de las visitas en los Museos de Madrid

# %% [markdown]
# ### Proyecto focalizado en el análisis de datos sobre los visitantes en los museos de la Comunidad de Madrid.
# *Revelación de patrones clave influenciados por factores estacionales, demográficos, económicos, interés cultural, oferta temática...*

# %% [markdown]
# # ⭐ Hipótesis principal del proyecto:
#
# Existen variaciones de interés culturales muy marcados según el género o la edad en las visitas a los principales museos de Madrid.
#
# ***
#
# ***
#
# ***

# %% [markdown]
# ## ⭐⭐⭐ Hipótesis secundarias:
#
# ***
#
# ***
#
# ***

# %% [markdown]
# ## 📅 Patrones estacionales
# Existen picos de visitas en **vacaciones** y **días festivos**, y se pueden identificar tendencias según el **día de la semana** o **eventos especiales**.
#
# ***
#
# ## 👥 Preferencias demográficas
# Los **jóvenes** prefieren museos de **arte contemporáneo**, mientras que las **personas mayores** optan por museos de **arte clásico o histórico**.
#
# ***
#
# ## 🏛️ Conservación y popularidad
# Las obras **mejor conservadas** atraen a más visitantes, y las **restauraciones** aumentan el interés de los visitantes.
#
# ***
#
# ## 🖼️ Afluencia y exposiciones temporales
# Las **exposiciones temporales** generan más visitas que las **colecciones permanentes**.
#
# ***
#
# ## 📊 Predicción del flujo de visitantes
# La afluencia puede predecirse mediante factores como el **clima** y **eventos locales**.
#
# ***
#
# ## 🔍 Recomendaciones personalizadas
# Algoritmos de **recomendación basados en intereses previos** pueden mejorar la **satisfacción** y aumentar las **visitas repetidas**.
#
# ***
#
# ## 🎨 Impacto de las restauraciones
# Las obras **recién restauradas** atraen más visitantes que las que no han sido **renovadas recientemente**.
#
# ***
#
# ## ✈️ Segmentación por origen y edad
# Los **turistas internacionales** prefieren museos **históricos**, mientras que los **locales** tienden a interesarse por museos **más contemporáneos**.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

# %%
fuente_datos_museos_1 = "https://datos.gob.es/es/catalogo/l01280796-museos-de-la-ciudad-de-madrid"
datos_museos_1 = pd.read_csv('./datos/otros_datos/https-datos-madrid-es-egob-catalogo-201132-0-museos-3.csv', sep=";", encoding='latin')
datos_museos_1.head()
# Out:
#         PK                          NOMBRE  \
# 0  6017808       Casa Museo Fuente del Rey
# 1  4847190         Casa Museo Lope de Vega
# 2  4949641  Casita - Museo del Ratón Pérez
# 3  5682031          Castillo de la Alameda
# 4     2064          Casón del Buen Retiro.
#
#                                  DESCRIPCION-ENTIDAD  \
# 0  Fundación AMYC (Arte Moderno y Contemporáneo)....
# 1  'Mi casilla, mi quietud, mi g&amp;uuml;ertecil...
# 2  La Casita-Museo de Ratón Pérez, constituye un ...
# 3  El Castillo de la Alameda o de Barajas es uno ...
# 4  El Centro de Estudios del Prado está ubicado e...
#
#                                              HORARIO EQUIPAMIENTO  \
# 0  Martes a sábado, de 10 a 19 horas. Lunes, domi...          NaN
# 1  De martes a domingo, de 10 a 18 horas.  Cerrad...          NaN
# 2  Visitas familiares:    Lunes a viernes:  de 11...          NaN
# 3  Abierto solo en fin de semana (sábado y doming...   Zona wifi.
# 4                                                NaN          NaN
#
#                                           TRANSPORTE  \
# 0                                          Bus: 161.
# 1  Metro: Antón Martín (línea 1), Sevilla (línea ...
# 2  Metro: Sol (líneas: 1, 2 y 3), Ópera (líneas 2...
# 3   Metro: Alameda de Osuna y El Capricho (línea 5).
# 4  Metro: Estación del Arte (línea 1), Banco de E...
#
#                                          DESCRIPCION ACCESIBILIDAD  \
# 0                                                NaN             3
# 1                                                NaN           0,4
# 2  Se aconseja acudan con la entrada adquirida an...             0
# 3  Accesibilidad   Rampas de acceso (las rampas d...           1,6
# 4  Descripción monumental  El Casón o Salón de Ba...             1
#
#                                          CONTENT-URL      NOMBRE-VIA  ...  \
# 0  http://www.madrid.es/sites/v/index.jsp?vgnextc...  FUENTE DEL REY  ...
# 1  http://www.madrid.es/sites/v/index.jsp?vgnextc...       CERVANTES  ...
# 2  http://www.madrid.es/sites/v/index.jsp?vgnextc...          ARENAL  ...
# 3  http://www.madrid.es/sites/v/index.jsp?vgnextc...  ANTONIO SANCHA  ...
# 4  http://www.madrid.es/sites/v/index.jsp?vgnextc...     ALFONSO XII  ...
#
#   COD-DISTRITO         DISTRITO  COORDENADA-X COORDENADA-Y    LATITUD  \
# 0            9  MONCLOA-ARAVACA        434663      4478596  40.455469
# 1            1           CENTRO        440825      4473983  40.414369
# 2            1           CENTRO        440144      4474287  40.417060
# 3           21          BARAJAS        449698      4478802  40.458365
# 4            3           RETIRO        441525      4474078  40.415275
#
#    LONGITUD     TELEFONO  FAX                             EMAIL  \
# 0 -3.770572  913 579 116  NaN            info@fundacionamyc.org
# 1 -3.697467  914 299 216  NaN    casamuseolopedevega@madrid.org
# 2 -3.705520  915 226 968  NaN       info@casamuseoratonperez.es
# 3 -3.593276  913 667 415  NaN         castilloalameda@madrid.es
# 4 -3.689222  913 302 821  NaN  centro.estudios@museodelprado.es
#
#                                                 TIPO
# 0  /contenido/entidadesYorganismos/FundacionesCul...
# 1             /contenido/entidadesYorganismos/Museos
# 2             /contenido/entidadesYorganismos/Museos
# 3  /contenido/entidadesYorganismos/MonumentosEdif...
# 4  /contenido/entidadesYorganismos/MonumentosEdif...
#
# [5 rows x 32 columns]

# %%
fuente_datos_museos_2 = "https://datos.gob.es/es/catalogo/l01280796-estudio-de-satisfaccion-de-las-personas-usuarias-de-los-museos-y-exposiciones-municipales"
datos_museos_2 = pd.read_csv("./datos/otros_datos/estudioSatisfaccion2023.csv", sep=";", encoding='utf-8')
datos_museos_2.head()
# Out:
#          id           start_date         updated_date  survey_id    status  \
# 0  37450270  2023-05-31 09:54:47  2023-05-31 09:55:20     311750  Completa
# 1  37450281  2023-05-31 09:56:51  2023-05-31 09:57:25     311750  Completa
# 2  37450382  2023-05-31 10:18:55  2023-05-31 10:19:24     311750  Completa
# 3  37465668  2023-06-01 09:58:36  2023-06-01 09:59:06     311750  Completa
# 4  37467717  2023-06-01 12:06:55  2023-06-01 12:07:20     311750  Completa
#
#   device_type       1_¿Qué museo acabas de visitar?  \
# 0      Mobile                    Arte Contemporáneo
# 1      Mobile                    Historia de Madrid
# 2      Mobile                    Historia de Madrid
# 3      Mobile  Imprenta Municipal - Artes del Libro
# 4     Desktop                Castillo de la Alameda
#
#    2_La recepción y atención al público  \
# 0                                   9.0
# 1                                   9.0
# 2                                   7.0
# 3                                   8.0
# 4                                   9.0
#
#    3_La información: paneles, folletos, cartelas ...  \
# 0                                                9.0
# 1                                                9.0
# 2                                                9.0
# 3                                                9.0
# 4                                                9.0
#
#    4_El confort, el orden y la limpieza en la visita  \
# 0                                                9.0
# 1                                                7.0
# 2                                                7.0
# 3                                                9.0
# 4                                                7.0
#
#    5_La adaptación a visitantes con discapacidad   \
# 0                                             7.0
# 1                                             7.0
# 2                                             7.0
# 3                                             9.0
# 4                                             8.0
#
#    6_Teniendo en cuenta toda su experiencia, ¿cuál es su valoración global con la visita  en una escala de 0 a 10, siendo “0”, totalmente insatisfactoria y “10”, totalmente satisfactoria  \
# 0                                               10.0
# 1                                                8.0
# 2                                                9.0
# 3                                                7.0
# 4                                                9.0
#
#   7_Nos encantaría recibir sus observaciones, comentarios o recomendaciones para ayudarnos a mejorar el servicio  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   8_¿Cuál es su grupo de edad? 9_¿Cuál es su sexo?
# 0              De 41 a 65 años                 NaN
# 1              De 41 a 65 años                 NaN
# 2              De 18 a 25 años                 NaN
# 3              De 26 a 40 años                Otro
# 4             De 66 o más años                 NaN

# %%
fuente_datos_museos_2 = "https://datos.gob.es/es/catalogo/l01280796-museos-de-la-ciudad-de-madrid"
datos_museos_3 = pd.read_csv("./datos/otros_datos/actividades_culturales.csv", sep=",", encoding='utf-8')
datos_museos_3.head()
# Out:
#                                           Unnamed: 0  Hombres_2021  \
# 0  Visitaron museos, exposiciones y galerías de arte          26.5
# 1                                             Museos          20.8
# 2                                       Exposiciones          15.2
# 3                                   Galerías de arte           7.7
# 4                 Visitaron monumentos y yacimientos          30.0
#
#    Hombres_2018  Hombres_2014  Hombres_2010  Mujeres_2021  Mujeres_2018  \
# 0          46.5          38.8          38.1          24.6          46.9
# 1          40.0          32.3          30.7          19.5          40.9
# 2          29.7          23.5          25.2          13.9          29.9
# 3          15.0          12.0          13.5           6.1          17.0
# 4          51.7          43.2          42.7          26.6          50.0
#
#    Mujeres_2014  Mujeres_2010
# 0          40.1          37.6
# 1          34.2          30.5
# 2          24.1          26.2
# 3          13.4          13.7
# 4          42.3          38.8

# %%
fuente_datos_museos_4 = "https://datos.gob.es/es/catalogo/l01280796-estudio-de-satisfaccion-de-las-personas-usuarias-de-los-museos-y-exposiciones-municipales"
datos_museos_4 = pd.read_csv("./datos/otros_datos/MuseosdeMadrid_-1519955177370181428.csv", sep=",", encoding='utf-8')
datos_museos_4.head()
# Out:
#    OBJECTID                                      NOMBRE           CALLE  NUM  \
# 0         1                     Casa Museo Lope de Vega       CERVANTES   11
# 1         2              Casita - Museo del Ratón Pérez          ARENAL    8
# 2         3                      Castillo de la Alameda  ANTONIO SANCHA    1
# 3         4                       Casón del Buen Retiro     ALFONSO XII   28
# 4         5  Centro Social y Cultural La Casa Encendida        VALENCIA    2
#
#   LOCALIDAD  CODIGO-POSTAL            BARRIO DISTRITO  \
# 0    MADRID          28014            CORTES   CENTRO
# 1    MADRID          28013               SOL   CENTRO
# 2    MADRID          28042  ALAMEDA DE OSUNA  BARAJAS
# 3    MADRID          28014     LOS JERONIMOS   RETIRO
# 4    MADRID          28012       EMBAJADORES   CENTRO
#
#                                             TELEFONO  \
# 0                                        914 299 216
# 1                                        915 226 968
# 2  913 667 415                                   ...
# 3                          913 304 016 / 913 302 821
# 4  902 430 322                                   ...
#
#                             EMAIL              x             y
# 0                             NaN  440824.999971  4.473983e+06
# 1     info@casamuseoratonperez.es  440253.999978  4.474494e+06
# 2       castilloalameda@madrid.es  449698.000021  4.478802e+06
# 3     biblioteca@museodelprado.es  441635.000010  4.474285e+06
# 4  lacasaencendida@montemadrid.es  440621.999971  4.473051e+06

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_usuarios_2024 = pd.read_csv("./datos/JOBO/JOBO_usuarios_2024.csv", sep=";", encoding='utf-8')
jobo_usuarios_2024.head()
# Out:
#    Fecha extracción  ID Fecha de nacimiento Ciudad País  Código postal
# 0  02/07/2024 11:30   7          03/07/1997    NaN  NaN            NaN
# 1  02/07/2024 11:30  12          03/07/1997    NaN  NaN            NaN
# 2  02/07/2024 11:30  13          03/07/1997    NaN  NaN            NaN
# 3  02/07/2024 11:30  18          03/07/1997    NaN  NaN            NaN
# 4  02/07/2024 11:30  19          03/07/1997    NaN  NaN            NaN

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_entradas_2024 = pd.read_csv("./datos/JOBO/JOBO_entradas_emitidas_2024.csv", sep=";", encoding='utf-8')
jobo_entradas_2024.head()
# Out:
#     Año      Mes           Organismo                                 Evento  \
# 0  2024    Enero  Teatro Circo Price                 CIRCO PRICE EN NAVIDAD
# 1  2024  Febrero  Teatro Circo Price                         MAGIA DE CERCA
# 2  2024  Febrero  Teatro Circo Price  GALA INTERNACIONAL DE MAGIA EN ESCENA
# 3  2024    Marzo  Teatro Circo Price                  À deux roues, la vie!
# 4  2024    Abril  Teatro Circo Price                                   NUYE
#
#    Entradas
# 0        28
# 1        85
# 2       516
# 3        13
# 4        95

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_usuarios_2023 = pd.read_csv("./datos/JOBO/JOBO_usuarios_2023.csv", sep=";", encoding='utf-8')
jobo_usuarios_2023.head()
# Out:
#    Fecha extracción Fecha de nacimiento    Ciudad    País  Código postal  \
# 0  23/01/2024 14:20          21/11/1997  A CORUÑA  España        15009.0
# 1  23/01/2024 14:20          15/12/1997  A CORUÑA  España        15110.0
# 2  23/01/2024 14:20          30/01/1998  A CORUÑA  España        15007.0
# 3  23/01/2024 14:20          21/11/1998  A CORUÑA  España        15011.0
# 4  23/01/2024 14:20          12/12/1999  A CORUÑA  España        15660.0
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_entradas_2023 = pd.read_csv("./datos/JOBO/JOBO_entradas_emitidas_2023.csv", sep=";", encoding='utf-8')
jobo_entradas_2023.head()
# Out:
#     Año      Mes    Organismo                                 Evento  Entradas
# 0  2023    enero  Circo Price                 CIRCO PRICE EN NAVIDAD        59
# 1  2023  febrero  Circo Price  GALA INTERNACIONAL DE MAGIA EN ESCENA       247
# 2  2023  febrero  Circo Price                         MAGIA DE CERCA        43
# 3  2023    marzo  Circo Price                         EL VENTRÍLOCUO        34
# 4  2023    marzo  Circo Price  GALA INTERNACIONAL DE MAGIA EN ESCENA       233

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_usuarios_2022 = pd.read_csv("./datos/JOBO/JOBO_usuarios_2022.csv", sep=";", encoding='utf-8')
jobo_usuarios_2022.head()
# Out:
#   Fecha descarga Fecha nacimiento    Ciudad  Código Postal
# 0   7-7-22 14:01       28/03/1996  A CORUÑA        15174.0
# 1   7-7-22 14:01       28/08/1995  A CORUÑA        15704.0
# 2   7-7-22 14:01       19/09/1996  A CORUÑA        15006.0
# 3   7-7-22 14:01       21/11/1997  A CORUÑA        15009.0
# 4   7-7-22 14:01       15/12/1997  A CORUÑA        15110.0

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_entradas_2022 = pd.read_csv("./datos/JOBO/JOBO_entradas_emitidas_2022.csv", sep=";", encoding='utf-8')
jobo_entradas_2022.head()
# Out:
#       Año    Mes Organismo                     Evento  Entradas
# 0  2022.0  abril  Cineteca          Adiós al lenguaje      17.0
# 1  2022.0  abril  Cineteca             Bajo el volcán       7.0
# 2  2022.0  abril  Cineteca            Bella durmiente       5.0
# 3  2022.0  abril  Cineteca        El almuerzo desnudo      24.0
# 4  2022.0  abril  Cineteca  El cantar de los cantares      15.0

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_usuarios_2021 = pd.read_csv("./datos/JOBO/JOBO_usuarios_2021.csv", sep=";", encoding='utf-8')
jobo_usuarios_2021.head()
# Out:
#   Fecha descarga Fecha de nacimiento    Ciudad    País Código postal
# 0     02/07/2021          28/03/1996  A CORUÑA  España         15174
# 1     02/07/2021          21/11/1998  A CORUÑA  España         15011
# 2     02/07/2021          15/12/1997  A CORUÑA  España         15110
# 3     02/07/2021          12/12/1999  A CORUÑA  España         15660
# 4     02/07/2021          19/09/1996  A CORUÑA  España         15006

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_entradas_2021 = pd.read_csv("./datos/JOBO/JOBO_entradas_emitidas_2021.csv", sep=";", encoding='utf-8')
jobo_entradas_2021.head()
# Out:
#     Año    Mes    Organismo                                            Evento  \
# 0  2021  enero  Conde Duque  Cine - El país de las maravillas - Le meraviglie
# 1  2021  enero  Conde Duque                                    Cine - Fukuoka
# 2  2021  enero  Conde Duque     Cine - Los jóvenes del barrio + Aquells joves
# 3  2021  enero  Conde Duque                                 Música - Amorante
# 4  2021  enero  Conde Duque                                   Música - Jansky
#
#    Entradas
# 0         0
# 1        27
# 2        25
# 3        19
# 4         0

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_usuarios_2020 = pd.read_csv("./datos/JOBO/JOBO_usuarios_2020.csv", sep=";", encoding='latin')
jobo_usuarios_2020.head()
# Out:
#      Fecha descarga Tratamiento Fecha de nacimiento    Ciudad    País  \
# 0  07/01/2021 11:40       Señor          23/05/1994  A CAÑIZA  España
# 1  07/01/2021 11:40      Señora          28/03/1996  A CORUÑA  España
# 2  07/01/2021 11:40       Señor          21/11/1998  A CORUÑA  España
# 3  07/01/2021 11:40      Señora          15/03/1994  A CORUÑA  España
# 4  07/01/2021 11:40       Señor          15/12/1997  A CORUÑA  España
#
#   Código postal
# 0         36880
# 1         15174
# 2         15011
# 3         15004
# 4         15110

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_entradas_2020 = pd.read_csv("./datos/JOBO/JOBO_entradas_emitidas_2020.csv", sep=";", encoding='latin')
jobo_entradas_2020.head()
# Out:
#     Año    Mes Organismo                                   Evento  Entradas
# 0  2020  Enero  Cineteca                An elephant sitting still      54.0
# 1  2020  Enero  Cineteca                             Another year      30.0
# 2  2020  Enero  Cineteca                             Ask Dr. Ruth      58.0
# 3  2020  Enero  Cineteca  Blow-up (Deseo de una mañana de verano)      60.0
# 4  2020  Enero  Cineteca                        Caché (Escondido)      60.0

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_usuarios_2019 = pd.read_csv("./datos/JOBO/JOBO_usuarios_2019.csv", sep=";", encoding='latin')
jobo_usuarios_2019.head()
# Out:
#   Fecha descarga Tratamiento Fecha de nacimiento    Ciudad    País  \
# 0   3-1-20 16:40       Señor          23/05/1994  A CAÑIZA  España
# 1   3-1-20 16:40       Señor          21/11/1998  A CORUÑA  España
# 2   3-1-20 16:40      Señora          28/03/1996  A CORUÑA  España
# 3   3-1-20 16:40      Señora          15/03/1994  A CORUÑA  España
# 4   3-1-20 16:40      Señora          30/04/1996  A CORUÑA  España
#
#   Código postal
# 0         36880
# 1         15011
# 2         15174
# 3         15004
# 4         15004

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_entradas_2019 = pd.read_csv("./datos/JOBO/JOBO_entradas_emitidas_2019.csv", sep=";", encoding='latin')
jobo_entradas_2019.head()
# Out:
#     Año    Mes Organismo                                             Evento  \
# 0  2019  Enero  Cineteca                                         Bertsolari
# 1  2019  Enero  Cineteca    Bowie, back to earth: The man who fell to earth
# 2  2019  Enero  Cineteca  Bowie, back to earth: Twin Peaks. Fuego camina...
# 3  2019  Enero  Cineteca                                   I see red people
# 4  2019  Enero  Cineteca                               Last days in Shibati
#
#    Entradas
# 0      55.0
# 1      64.0
# 2      32.0
# 3      90.0
# 4      52.0

# %%
fuente_jobo = "https://datos.gob.es/es/catalogo/l01280796-jobo-joven-bono-cultural-entradas-emitidas-y-personas-usuarias"
jobo_entradas_2018 = pd.read_csv("./datos/JOBO/JOBO_entradas_2018.csv", sep=";", encoding='latin')
jobo_entradas_2018.head()
# Out:
#    Año Evento Mes Evento Organismo  \
# 0        2018      Enero  Cineteca
# 1        2018      Enero  Cineteca
# 2        2018      Enero  Cineteca
# 3        2018      Enero  Cineteca
# 4        2018      Enero  Cineteca
#
#                                          Evento  Entradas
# 0                                       Amazona      10.0
# 1       CICLO DOCMA: El becerro pintado + Oírse       9.0
# 2  CICLO LA CÁMARA COMO ESCRITURA. PRIMO LEJANO       5.0
# 3               DOCSBARCELONA DEL MES. Machines      10.0
# 4                El séptimo de Cineteca. Muziko       2.0

# %%
tarifas = pd.read_csv("./datos/VISITANTES_GENERAL/tarifas_museos_madrid.csv", sep=",", encoding='utf-8')
tarifas.head()
# Out:
#    Unnamed: 0                        Museo Entrada general  \
# 0           0              Museo del Prado             15€
# 1           1            Museo Reina Sofía             10€
# 2           2     Museo Thyssen-Bornemisza             13€
# 3           3  Museo Arqueológico Nacional              3€
# 4           4                Museo Sorolla              3€
#
#                                         Día gratuito  \
# 0   Lunes a Sábado 18:00-20:00, Domingos 17:00-19:00
# 1  Lunes y Miércoles a Sábado 19:00-21:00, Doming...
# 2           Lunes 12:00-16:00 (colección permanente)
# 3           Sábados desde 14:00, Domingos y festivos
# 4           Sábados desde 14:00, Domingos y festivos
#
#                       Precio reducido                    Descuento por edad  \
# 0  7,50€ (estudiantes, mayores de 65)  Gratis menores de 18 y mayores de 65
# 1     8€ (estudiantes, mayores de 65)  Gratis menores de 18 y mayores de 65
# 2     9€ (estudiantes, mayores de 65)  Gratis menores de 18 y mayores de 65
# 3  1,50€ (estudiantes, mayores de 65)  Gratis menores de 18 y mayores de 65
# 4  1,50€ (estudiantes, mayores de 65)  Gratis menores de 18 y mayores de 65
#
#                                Notas adicionales
# 0             Entrada gratuita para desempleados
# 1           Gratis para jubilados y desempleados
# 2  Entrada combinada con exposiciones temporales
# 3           Entrada gratuita en fechas señaladas
# 4              Exposiciones temporales incluidas

# %%
visitantes = pd.read_csv("./datos/VISITANTES_GENERAL/visitantes_museos_madrid_visitas.csv", sep=",", encoding='utf-8')
visitantes.head()
# Out:
#    Unnamed: 0                     Museo  Visitantes_Hombres (%)  \
# 0           0           Museo del Prado                      45
# 1           1         Museo Reina Sofía                      43
# 2           2   Museo Santiago Bernabéu                      60
# 3           3  Museo Thyssen-Bornemisza                      47
# 4           4         CaixaForum Madrid                      44
#
#    Visitantes_Mujeres (%)  Edad_<18 (%)  Edad_18-35 (%)  Edad_36-50 (%)  \
# 0                      55            10              35              30
# 1                      57            12              40              25
# 2                      40            15              45              30
# 3                      53             9              38              28
# 4                      56            11              39              28
#
#    Edad_>50 (%)  Locales (%)  Nacionales (%)  Internacionales (%)
# 0            25           40              35                   25
# 1            23           35              40                   25
# 2            10           30              40                   30
# 3            25           30              35                   35
# 4            22           32              38                   30

# %%
visitantes_renta_estudios = pd.read_csv("./datos/VISITANTES_GENERAL/visitantes_museos_madrid_amplio.csv", sep=",", encoding='utf-8')
visitantes_renta_estudios.head()
# Out:
#                                   Museo      Género Renta Anual (€)  \
# 0  Museo Nacional de Ciencias Naturales  No Binario        >40,000€
# 1  Museo Nacional de Ciencias Naturales  No Binario        <20,000€
# 2                         Museo Sorolla  No Binario        <20,000€
# 3                     CaixaForum Madrid   Masculino        <20,000€
# 4                         Museo Sorolla  No Binario        >40,000€
#
#          Nivel de Estudios   Edad  Visitantes por Grupo
# 0       Educación Primaria  18-35                   115
# 1     Educación Secundaria    >50                    98
# 2       Educación Primaria    <18                   151
# 3  Estudios Universitarios    <18                    45
# 4    Postgrado o Doctorado    <18                   176

# %% [markdown]
# ---
#
# ***

# %%
caixa_forum = pd.read_csv("./datos/MUSEOS_INDIVIDUALES/caixaforum_madrid_visitantes_filtrados.csv", sep=",", encoding='utf-8')
caixa_forum.head()
# Out:
#                Museo     Género    Renta Anual (€)        Nivel de Estudios  \
# 0  CaixaForum Madrid   Femenino           >40,000€    Postgrado o Doctorado
# 1  CaixaForum Madrid  Masculino           <20,000€  Estudios Universitarios
# 2  CaixaForum Madrid  Masculino  20,000€ - 40,000€       Educación Primaria
# 3  CaixaForum Madrid   Femenino  20,000€ - 40,000€    Postgrado o Doctorado
# 4  CaixaForum Madrid   Femenino  20,000€ - 40,000€       Educación Primaria
#
#     Edad  Locales (%)  Nacionales (%)  Internacionales (%)  \
# 0    >50           35              14                   32
# 1    <18           50              22                   21
# 2    >50           38              35                   12
# 3    <18           30              15                   15
# 4  36-50           50              14                   32
#
#    Visitantes por Grupo  Porcentaje Locales (%)  Porcentaje Nacionales (%)  \
# 0                     4               43.209877                  17.283951
# 1                   136               53.763441                  23.655914
# 2                   163               44.705882                  41.176471
# 3                    32               50.000000                  25.000000
# 4                   107               52.083333                  14.583333
#
#    Porcentaje Internacionales (%)
# 0                       39.506173
# 1                       22.580645
# 2                       14.117647
# 3                       25.000000
# 4                       33.333333

# %%
arqueologico = pd.read_csv("./datos/MUSEOS_INDIVIDUALES/museo_arqueológico_nacional_visitantes_filtrados.csv", sep=",", encoding='utf-8')
arqueologico.head()
# Out:
#                          Museo     Género    Renta Anual (€)  \
# 0  Museo Arqueológico Nacional   Femenino           >40,000€
# 1  Museo Arqueológico Nacional  Masculino           >40,000€
# 2  Museo Arqueológico Nacional   Femenino  20,000€ - 40,000€
# 3  Museo Arqueológico Nacional  Masculino  20,000€ - 40,000€
# 4  Museo Arqueológico Nacional   Femenino  20,000€ - 40,000€
#
#          Nivel de Estudios   Edad  Locales (%)  Nacionales (%)  \
# 0    Postgrado o Doctorado    <18           34              49
# 1    Postgrado o Doctorado    <18           65              13
# 2  Estudios Universitarios  18-35           20              14
# 3       Educación Primaria    <18           46              46
# 4  Estudios Universitarios    <18           52              45
#
#    Internacionales (%)  Visitantes por Grupo  Porcentaje Locales (%)  \
# 0                   18                    53               33.663366
# 1                   13                    75               71.428571
# 2                   39                    32               27.397260
# 3                   26                   156               38.983051
# 4                   30                   149               40.944882
#
#    Porcentaje Nacionales (%)  Porcentaje Internacionales (%)
# 0                  48.514851                       17.821782
# 1                  14.285714                       14.285714
# 2                  19.178082                       53.424658
# 3                  38.983051                       22.033898
# 4                  35.433071                       23.622047

# %%
cerralbo = pd.read_csv("./datos/MUSEOS_INDIVIDUALES/museo_cerralbo_visitantes_filtrados.csv", sep=",", encoding='utf-8')
cerralbo.head()
# Out:
#             Museo     Género    Renta Anual (€)        Nivel de Estudios  \
# 0  Museo Cerralbo   Femenino  20,000€ - 40,000€       Educación Primaria
# 1  Museo Cerralbo   Femenino           <20,000€     Educación Secundaria
# 2  Museo Cerralbo  Masculino           <20,000€  Estudios Universitarios
# 3  Museo Cerralbo   Femenino           >40,000€     Educación Secundaria
# 4  Museo Cerralbo  Masculino  20,000€ - 40,000€    Postgrado o Doctorado
#
#     Edad  Locales (%)  Nacionales (%)  Internacionales (%)  \
# 0    >50           21              11                   36
# 1  18-35           31              15                   38
# 2  18-35           61              20                   29
# 3  36-50           45              21                   37
# 4    >50           35              10                   22
#
#    Visitantes por Grupo  Porcentaje Locales (%)  Porcentaje Nacionales (%)  \
# 0                    70               30.882353                  16.176471
# 1                   176               36.904762                  17.857143
# 2                    63               55.454545                  18.181818
# 3                   125               43.689320                  20.388350
# 4                    11               52.238806                  14.925373
#
#    Porcentaje Internacionales (%)
# 0                       52.941176
# 1                       45.238095
# 2                       26.363636
# 3                       35.922330
# 4                       32.835821

# %%
historia_madrid = pd.read_csv("./datos/MUSEOS_INDIVIDUALES/museo_de_historia_de_madrid_visitantes_filtrados.csv", sep=",", encoding='utf-8')
historia_madrid.head()
# Out:
#                          Museo     Género    Renta Anual (€)  \
# 0  Museo de Historia de Madrid   Femenino           <20,000€
# 1  Museo de Historia de Madrid  Masculino  20,000€ - 40,000€
# 2  Museo de Historia de Madrid  Masculino           >40,000€
# 3  Museo de Historia de Madrid  Masculino  20,000€ - 40,000€
# 4  Museo de Historia de Madrid  Masculino  20,000€ - 40,000€
#
#          Nivel de Estudios   Edad  Locales (%)  Nacionales (%)  \
# 0       Educación Primaria    <18           40              17
# 1       Educación Primaria    <18           38              32
# 2  Estudios Universitarios  18-35           26              27
# 3       Educación Primaria    <18           30              16
# 4       Educación Primaria    <18           29              13
#
#    Internacionales (%)  Visitantes por Grupo  Porcentaje Locales (%)  \
# 0                   32                    65               44.943820
# 1                   23                    25               40.860215
# 2                   22                   107               34.666667
# 3                   21                    85               44.776119
# 4                   38                     1               36.250000
#
#    Porcentaje Nacionales (%)  Porcentaje Internacionales (%)
# 0                  19.101124                       35.955056
# 1                  34.408602                       24.731183
# 2                  36.000000                       29.333333
# 3                  23.880597                       31.343284
# 4                  16.250000                       47.500000

# %%
prado = pd.read_csv("./datos/MUSEOS_INDIVIDUALES/museo_del_prado_visitantes_filtrados.csv", sep=",", encoding='utf-8')
prado.head()
# Out:
#              Museo     Género    Renta Anual (€)        Nivel de Estudios  \
# 0  Museo del Prado   Femenino  20,000€ - 40,000€  Estudios Universitarios
# 1  Museo del Prado  Masculino  20,000€ - 40,000€       Educación Primaria
# 2  Museo del Prado  Masculino           <20,000€  Estudios Universitarios
# 3  Museo del Prado   Femenino           >40,000€    Postgrado o Doctorado
# 4  Museo del Prado  Masculino           <20,000€    Postgrado o Doctorado
#
#     Edad  Locales (%)  Nacionales (%)  Internacionales (%)  \
# 0  18-35           69              43                   23
# 1  36-50           46              35                   18
# 2  36-50           40              19                   14
# 3    >50           44              33                   18
# 4    >50           60              39                   19
#
#    Visitantes por Grupo  Porcentaje Locales (%)  Porcentaje Nacionales (%)  \
# 0                   146               51.111111                  31.851852
# 1                   158               46.464646                  35.353535
# 2                    45               54.794521                  26.027397
# 3                   168               46.315789                  34.736842
# 4                    88               50.847458                  33.050847
#
#    Porcentaje Internacionales (%)
# 0                       17.037037
# 1                       18.181818
# 2                       19.178082
# 3                       18.947368
# 4                       16.101695

# %%
romanticismo = pd.read_csv("./datos/MUSEOS_INDIVIDUALES/museo_del_romanticismo_visitantes_filtrados.csv", sep=",", encoding='utf-8')
romanticismo.head()
# Out:
#                     Museo     Género    Renta Anual (€)  \
# 0  Museo del Romanticismo  Masculino           <20,000€
# 1  Museo del Romanticismo   Femenino  20,000€ - 40,000€
# 2  Museo del Romanticismo   Femenino           <20,000€
# 3  Museo del Romanticismo  Masculino           >40,000€
# 4  Museo del Romanticismo   Femenino           >40,000€
#
#          Nivel de Estudios   Edad  Locales (%)  Nacionales (%)  \
# 0  Estudios Universitarios    >50           52              26
# 1  Estudios Universitarios  36-50           30              45
# 2  Estudios Universitarios    >50           62              35
# 3    Postgrado o Doctorado  36-50           47              31
# 4     Educación Secundaria  18-35           48              46
#
#    Internacionales (%)  Visitantes por Grupo  Porcentaje Locales (%)  \
# 0                   20                    96               53.061224
# 1                   38                    12               26.548673
# 2                   35                    44               46.969697
# 3                   24                   103               46.078431
# 4                   26                    12               40.000000
#
#    Porcentaje Nacionales (%)  Porcentaje Internacionales (%)
# 0                  26.530612                       20.408163
# 1                  39.823009                       33.628319
# 2                  26.515152                       26.515152
# 3                  30.392157                       23.529412
# 4                  38.333333                       21.666667

# %%
nacional_de_ciencias_naturales = pd.read_csv("./datos/MUSEOS_INDIVIDUALES/museo_nacional_de_ciencias_naturales_visitantes_filtrados.csv", sep=",", encoding='utf-8')
nacional_de_ciencias_naturales.head()
# Out:
#                                   Museo     Género Renta Anual (€)  \
# 0  Museo Nacional de Ciencias Naturales  Masculino        <20,000€
# 1  Museo Nacional de Ciencias Naturales  Masculino        <20,000€
# 2  Museo Nacional de Ciencias Naturales  Masculino        >40,000€
# 3  Museo Nacional de Ciencias Naturales   Femenino        >40,000€
# 4  Museo Nacional de Ciencias Naturales   Femenino        >40,000€
#
#        Nivel de Estudios   Edad  Locales (%)  Nacionales (%)  \
# 0     Educación Primaria    >50           47              48
# 1   Educación Secundaria    >50           48              24
# 2  Postgrado o Doctorado  36-50           44              41
# 3     Educación Primaria    <18           50              35
# 4   Educación Secundaria  36-50           42              28
#
#    Internacionales (%)  Visitantes por Grupo  Porcentaje Locales (%)  \
# 0                   18                   160               41.592920
# 1                   35                   143               44.859813
# 2                   33                    73               37.288136
# 3                   18                    50               48.543689
# 4                   11                    21               51.851852
#
#    Porcentaje Nacionales (%)  Porcentaje Internacionales (%)
# 0                  42.477876                       15.929204
# 1                  22.429907                       32.710280
# 2                  34.745763                       27.966102
# 3                  33.980583                       17.475728
# 4                  34.567901                       13.580247

# %%
reina_sofia = pd.read_csv("./datos/MUSEOS_INDIVIDUALES/museo_reina_sofia_visitantes_filtrados.csv", sep=",", encoding='utf-8')
reina_sofia.head()
# Out:
#                Museo     Género    Renta Anual (€)        Nivel de Estudios  \
# 0  Museo Reina Sofía   Femenino  20,000€ - 40,000€  Estudios Universitarios
# 1  Museo Reina Sofía  Masculino           <20,000€       Educación Primaria
# 2  Museo Reina Sofía  Masculino  20,000€ - 40,000€  Estudios Universitarios
# 3  Museo Reina Sofía   Femenino  20,000€ - 40,000€  Estudios Universitarios
# 4  Museo Reina Sofía  Masculino           <20,000€       Educación Primaria
#
#     Edad  Locales (%)  Nacionales (%)  Internacionales (%)  \
# 0  18-35           64              47                   16
# 1  36-50           31              13                   25
# 2    <18           69              45                   29
# 3  36-50           55              28                   23
# 4    >50           66              28                   26
#
#    Visitantes por Grupo  Porcentaje Locales (%)  Porcentaje Nacionales (%)  \
# 0                    87               50.393701                  37.007874
# 1                   172               44.927536                  18.840580
# 2                   126               48.251748                  31.468531
# 3                   129               51.886792                  26.415094
# 4                    31               55.000000                  23.333333
#
#    Porcentaje Internacionales (%)
# 0                       12.598425
# 1                       36.231884
# 2                       20.279720
# 3                       21.698113
# 4                       21.666667

# %%
santiago_bernabeu = pd.read_csv("./datos/MUSEOS_INDIVIDUALES/museo_santiago_bernabeu_visitantes_filtrados.csv", sep=",", encoding='utf-8')
santiago_bernabeu.head()
# Out:
#                      Museo     Género    Renta Anual (€)  \
# 0  Museo Santiago Bernabéu   Femenino  20,000€ - 40,000€
# 1  Museo Santiago Bernabéu  Masculino           >40,000€
# 2  Museo Santiago Bernabéu  Masculino           >40,000€
# 3  Museo Santiago Bernabéu  Masculino           >40,000€
# 4  Museo Santiago Bernabéu  Masculino           <20,000€
#
#       Nivel de Estudios   Edad  Locales (%)  Nacionales (%)  \
# 0  Educación Secundaria    >50           61              22
# 1  Educación Secundaria  36-50           31              12
# 2  Educación Secundaria    <18           53              27
# 3    Educación Primaria  36-50           56              21
# 4    Educación Primaria  36-50           47              41
#
#    Internacionales (%)  Visitantes por Grupo  Porcentaje Locales (%)  \
# 0                   10                   105               65.591398
# 1                   24                    81               46.268657
# 2                   12                   133               57.608696
# 3                   38                    31               48.695652
# 4                   22                   190               42.727273
#
#    Porcentaje Nacionales (%)  Porcentaje Internacionales (%)
# 0                  23.655914                       10.752688
# 1                  17.910448                       35.820896
# 2                  29.347826                       13.043478
# 3                  18.260870                       33.043478
# 4                  37.272727                       20.000000

# %%
sorolla = pd.read_csv("./datos/MUSEOS_INDIVIDUALES/museo_sorolla_visitantes_filtrados.csv", sep=",", encoding='utf-8')
sorolla.head()
# Out:
#            Museo     Género    Renta Anual (€)        Nivel de Estudios  \
# 0  Museo Sorolla  Masculino           >40,000€       Educación Primaria
# 1  Museo Sorolla  Masculino  20,000€ - 40,000€       Educación Primaria
# 2  Museo Sorolla   Femenino           <20,000€     Educación Secundaria
# 3  Museo Sorolla   Femenino  20,000€ - 40,000€     Educación Secundaria
# 4  Museo Sorolla  Masculino  20,000€ - 40,000€  Estudios Universitarios
#
#     Edad  Locales (%)  Nacionales (%)  Internacionales (%)  \
# 0    <18           58              15                   31
# 1    >50           48              19                   23
# 2  18-35           43              33                   38
# 3    <18           38              49                   26
# 4    <18           60              38                   12
#
#    Visitantes por Grupo  Porcentaje Locales (%)  Porcentaje Nacionales (%)  \
# 0                    68               55.769231                  14.423077
# 1                   167               53.333333                  21.111111
# 2                    65               37.719298                  28.947368
# 3                   179               33.628319                  43.362832
# 4                    42               54.545455                  34.545455
#
#    Porcentaje Internacionales (%)
# 0                       29.807692
# 1                       25.555556
# 2                       33.333333
# 3                       23.008850
# 4                       10.909091

# %%
thyssen = pd.read_csv("./datos/MUSEOS_INDIVIDUALES/museo_thyssen_bornemisza_visitantes_filtrados.csv", sep=",", encoding='utf-8')
thyssen.head()
# Out:
#                       Museo     Género    Renta Anual (€)  \
# 0  Museo Thyssen-Bornemisza  Masculino           <20,000€
# 1  Museo Thyssen-Bornemisza  Masculino  20,000€ - 40,000€
# 2  Museo Thyssen-Bornemisza  Masculino           >40,000€
# 3  Museo Thyssen-Bornemisza   Femenino  20,000€ - 40,000€
# 4  Museo Thyssen-Bornemisza   Femenino  20,000€ - 40,000€
#
#          Nivel de Estudios   Edad  Locales (%)  Nacionales (%)  \
# 0       Educación Primaria    >50           61              22
# 1    Postgrado o Doctorado    >50           47              44
# 2       Educación Primaria  36-50           20              42
# 3     Educación Secundaria  18-35           64              27
# 4  Estudios Universitarios  36-50           40              32
#
#    Internacionales (%)  Visitantes por Grupo  Porcentaje Locales (%)  \
# 0                   18                     4               60.396040
# 1                   27                    49               39.830508
# 2                   26                   140               22.727273
# 3                   13                    46               61.538462
# 4                   20                    88               43.478261
#
#    Porcentaje Nacionales (%)  Porcentaje Internacionales (%)
# 0                  21.782178                       17.821782
# 1                  37.288136                       22.881356
# 2                  47.727273                       29.545455
# 3                  25.961538                       12.500000
# 4                  34.782609                       21.739130

# %% [markdown]
# ___
#
# ___
#
# Añadir Santiago Bernabéu, Caixa Forum, Fundación Telefónica....

# %% [markdown]
# **OUTLAYERS:** restauraciones chocantes, adquisiciones extraordinarias...

# %% [markdown]
# ![fin](./img/7ba470c8aec13d944d23e3f5865ef8f9.jpg)
